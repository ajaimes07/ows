# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
#import openweathermapy as ow
from pprint import pprint
import datetime
# Import API key
#from config import api_key

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %%
# Locations
csv_path = "locations.csv"
my_data = pd.read_csv(csv_path)

# %%
my_data.tail(5)
# Out:
#      Latitude  Longitude  Site ID
# 457   42.2626   -71.8023    424.0
# 458   42.2571   -71.8571    427.0
# 459   33.0151   -96.5389    328.0
# 460   39.6848   -83.9297    226.0
# 461   39.1700   -87.6400      NaN

# %%
my_data=my_data.dropna()

# %%
my_data.head(5)
# Out:
#    Latitude  Longitude  Site ID
# 0     44.98     -73.30    565.0
# 1     38.17    -122.26    448.0
# 2     40.38    -111.80    312.0
# 3     33.84    -117.91    570.0
# 4     45.20     -93.39    760.0

# %%
# List for holding lat_lngs and cities
lat_lngs = []

# %%
# Create a set of random lat and lng combinations
lats = my_data.filter(items=['Latitude'])
lngs = my_data.filter(items=['Longitude'])

# %%
lats.head(10)
# Out:
#    Latitude
# 0     44.98
# 1     38.17
# 2     40.38
# 3     33.84
# 4     45.20
# 5     34.50
# 6     44.25
# 7     44.25
# 8     43.47
# 9     43.47

# %%
lat_lngs = zip(lats, lngs)

# %%
# Create settings dictionary with information we're interested in
api_key = "079e2ccc90467ae079a158c3c9d3d609"
settings = {"units": "imperial", "appid": api_key}

# %%
# Starting URL for Weather Map API Call
url='http://api.openweathermap.org/data/2.5/weather?'
unit='imperial'
print('Beginning Data Retrieval')
print('------------------------')

# %%
def newpoint():
   return uniform(-180,180), uniform(-90, 90)

coord = (newpoint() for x in range(5000))

coordinates=[]
for coord in coord:
    coordinates.append(coord)
    
cities_original=[]
for coordinate_pair in coordinates:
    lat, lon= coordinate_pair
    cities_original.append(citipy.nearest_city(lat, lon).city_name)
    
cities=set(cities_original)
print(f'Numbers of unique cities used for data retrieving is {len(cities)}')
# Out:
# 626

# %%
url='http://api.openweathermap.org/data/2.5/weather?'
api_key='079e2ccc90467ae079a158c3c9d3d609'
unit='imperial'

query_url=f'{url}&appid={api_key}&unit={unit}&q='

lat=[]
long=[]
temp_max=[]
hum=[]
cld=[]
wind=[]
cit=[]
country=[]
date=[]
nums= 1

print('Beginning Data retrieval')
print('------------------------')
for city in cities:
    response_json=requests.get(query_url+city).json()
    if str(response_json['cod'])=='404':
        print(f'Missing data city no. {nums} of {len(cities)}|Skipped {city}')
        nums=nums + 1
    if str(response_json['cod'])!='404':
        try:
            cit.append(city)
            lat.append(response_json['coord']['lat'])
            print(f'Retrieve data city no. {nums} of {len(cities)}|Added {city}')
            nums=nums+1
        except:
            print('NA')
        try:
            long.append(response_json['coord']['lon'])
        except:
            print('NA')
        try:
            temp_max.append(response_json['main']['temp_max'])
        except:
            print('NA0')
        try:
            hum.append(response_json['main']['humidity'])
        except:
            print('NA1')
        try:
            cld.append(response_json['clouds']['all'])
        except:
            print('NA2')
        try:
            wind.append(response_json['wind']['speed'])
        except:
            print('NA3')
        try:
            country.append(response_json['sys']['country'])
        except:
            print('NA4')
        try:
            date.append(response_json['dt'])
        except:
            print('NA5')
print('----------------------')
print('End of Data retrieval')
# Out:
# Beginning Data retrieval
# ------------------------
# Retrieve data city no. 1 of 626|Added chuy
# Retrieve data city no. 2 of 626|Added casma
# Missing data city no. 3 of 626|Skipped sinkat
# Retrieve data city no. 4 of 626|Added hermanus
# Retrieve data city no. 5 of 626|Added iralaya
# Retrieve data city no. 6 of 626|Added east london
# Retrieve data city no. 7 of 626|Added sitka
# Retrieve data city no. 8 of 626|Added pevek
# Retrieve data city no. 9 of 626|Added tura
# Retrieve data city no. 10 of 626|Added yellowknife
# Retrieve data city no. 11 of 626|Added laguna
# Retrieve data city no. 12 of 626|Added bengkulu
# Missing data city no. 13 of 626|Skipped umzimvubu
# Missing data city no. 14 of 626|Skipped illoqqortoormiut
# Retrieve data city no. 15 of 626|Added yeniseysk
# Retrieve data city no. 16 of 626|Added albany
# Retrieve data city no. 17 of 626|Added bamako
# Retrieve data city no. 18 of 626|Added fairbanks
# Retrieve data city no. 19 of 626|Added rikitea
# Retrieve data city no. 20 of 626|Added cabo san lucas
# Retrieve data city no. 21 of 626|Added broome
# Retrieve data city no. 22 of 626|Added alofi
# Retrieve data city no. 23 of 626|Added ushuaia
# Retrieve data city no. 24 of 626|Added narsaq
# Retrieve data city no. 25 of 626|Added boralday
# Retrieve data city no. 26 of 626|Added guipavas
# Retrieve data city no. 27 of 626|Added powell
# Retrieve data city no. 28 of 626|Added katsuura
# Retrieve data city no. 29 of 626|Added souillac
# Retrieve data city no. 30 of 626|Added kapaa
# Retrieve data city no. 31 of 626|Added punta arenas
# Retrieve data city no. 32 of 626|Added taoudenni
# Retrieve data city no. 33 of 626|Added atuona
# Retrieve data city no. 34 of 626|Added kavieng
# Retrieve data city no. 35 of 626|Added komsomolskiy
# Retrieve data city no. 36 of 626|Added verkhnevilyuysk
# Missing data city no. 37 of 626|Skipped taolanaro
# Retrieve data city no. 38 of 626|Added barrow
# Retrieve data city no. 39 of 626|Added bluff
# Retrieve data city no. 40 of 626|Added carauari
# Retrieve data city no. 41 of 626|Added mananjary
# Retrieve data city no. 42 of 626|Added quatre cocos
# Retrieve data city no. 43 of 626|Added avarua
# Retrieve data city no. 44 of 626|Added dunedin
# Retrieve data city no. 45 of 626|Added victor harbor
# Retrieve data city no. 46 of 626|Added port alfred
# Retrieve data city no. 47 of 626|Added mataura
# Retrieve data city no. 48 of 626|Added norman wells
# Retrieve data city no. 49 of 626|Added roseburg
# Retrieve data city no. 50 of 626|Added leningradskiy
# Retrieve data city no. 51 of 626|Added hithadhoo
# Retrieve data city no. 52 of 626|Added gueugnon
# Retrieve data city no. 53 of 626|Added worcester
# Missing data city no. 54 of 626|Skipped tsihombe
# Retrieve data city no. 55 of 626|Added tuktoyaktuk
# Retrieve data city no. 56 of 626|Added bazarnyy syzgan
# Retrieve data city no. 57 of 626|Added batagay-alyta
# Retrieve data city no. 58 of 626|Added jamestown
# Retrieve data city no. 59 of 626|Added hobart
# Missing data city no. 60 of 626|Skipped yomitan
# Retrieve data city no. 61 of 626|Added cherskiy
# Retrieve data city no. 62 of 626|Added butaritari
# Retrieve data city no. 63 of 626|Added busselton
# Retrieve data city no. 64 of 626|Added bredasdorp
# Retrieve data city no. 65 of 626|Added olkhovatka
# Retrieve data city no. 66 of 626|Added padang
# Retrieve data city no. 67 of 626|Added arraial do cabo
# Retrieve data city no. 68 of 626|Added matara
# Retrieve data city no. 69 of 626|Added scalea
# Retrieve data city no. 70 of 626|Added vestmannaeyjar
# Missing data city no. 71 of 626|Skipped belushya guba
# Retrieve data city no. 72 of 626|Added kamenka
# Retrieve data city no. 73 of 626|Added vaini
# Retrieve data city no. 74 of 626|Added amvrosiyivka
# Retrieve data city no. 75 of 626|Added puerto del rosario
# Retrieve data city no. 76 of 626|Added nizhniy odes
# Retrieve data city no. 77 of 626|Added bhatkal
# Retrieve data city no. 78 of 626|Added gat
# Retrieve data city no. 79 of 626|Added esperance
# Retrieve data city no. 80 of 626|Added westport
# Missing data city no. 81 of 626|Skipped tumannyy
# Retrieve data city no. 82 of 626|Added wattegama
# Retrieve data city no. 83 of 626|Added puerto ayora
# Retrieve data city no. 84 of 626|Added kautokeino
# Retrieve data city no. 85 of 626|Added kodiak
# Retrieve data city no. 86 of 626|Added thompson
# Retrieve data city no. 87 of 626|Added lugovoy
# Retrieve data city no. 88 of 626|Added tuatapere
# Retrieve data city no. 89 of 626|Added robinson
# Retrieve data city no. 90 of 626|Added tomatlan
# Retrieve data city no. 91 of 626|Added zhigansk
# Retrieve data city no. 92 of 626|Added saint-francois
# Retrieve data city no. 93 of 626|Added aulnoye-aymeries
# Retrieve data city no. 94 of 626|Added husavik
# Retrieve data city no. 95 of 626|Added upernavik
# Retrieve data city no. 96 of 626|Added bethel
# Retrieve data city no. 97 of 626|Added geraldton
# Retrieve data city no. 98 of 626|Added presidente dutra
# Retrieve data city no. 99 of 626|Added dawei
# Retrieve data city no. 100 of 626|Added iqaluit
# Retrieve data city no. 101 of 626|Added new norfolk
# Retrieve data city no. 102 of 626|Added almaznyy
# Missing data city no. 103 of 626|Skipped umm durman
# Retrieve data city no. 104 of 626|Added kaitangata
# Retrieve data city no. 105 of 626|Added grand gaube
# Retrieve data city no. 106 of 626|Added yantal
# Retrieve data city no. 107 of 626|Added salinas
# Retrieve data city no. 108 of 626|Added georgetown
# Missing data city no. 109 of 626|Skipped straldza
# Retrieve data city no. 110 of 626|Added harper
# Retrieve data city no. 111 of 626|Added bulalacao
# Retrieve data city no. 112 of 626|Added kamaishi
# Retrieve data city no. 113 of 626|Added krasnyy bogatyr
# Retrieve data city no. 114 of 626|Added port macquarie
# Retrieve data city no. 115 of 626|Added namatanai
# Missing data city no. 116 of 626|Skipped vaitupu
# Retrieve data city no. 117 of 626|Added moussoro
# Retrieve data city no. 118 of 626|Added bangkalan
# Retrieve data city no. 119 of 626|Added lasa
# Retrieve data city no. 120 of 626|Added poum
# Retrieve data city no. 121 of 626|Added nambucca heads
# Retrieve data city no. 122 of 626|Added cockburn town
# Retrieve data city no. 123 of 626|Added cordoba
# Missing data city no. 124 of 626|Skipped bolshiye chapurniki
# Retrieve data city no. 125 of 626|Added ugoofaaru
# Retrieve data city no. 126 of 626|Added bastia
# Retrieve data city no. 127 of 626|Added chokurdakh
# Retrieve data city no. 128 of 626|Added kuah
# Retrieve data city no. 129 of 626|Added sola
# Retrieve data city no. 130 of 626|Added beloha
# Retrieve data city no. 131 of 626|Added novoukrayinka
# Retrieve data city no. 132 of 626|Added itarema
# Retrieve data city no. 133 of 626|Added asau
# Retrieve data city no. 134 of 626|Added batetskiy
# Retrieve data city no. 135 of 626|Added basco
# Retrieve data city no. 136 of 626|Added lavrentiya
# Retrieve data city no. 137 of 626|Added ribas do rio pardo
# Retrieve data city no. 138 of 626|Added wanning
# Retrieve data city no. 139 of 626|Added cape town
# Retrieve data city no. 140 of 626|Added panaba
# Retrieve data city no. 141 of 626|Added kulhudhuffushi
# Missing data city no. 142 of 626|Skipped chagda
# Retrieve data city no. 143 of 626|Added santa marta de tormes
# Retrieve data city no. 144 of 626|Added rockport
# Retrieve data city no. 145 of 626|Added biltine
# Retrieve data city no. 146 of 626|Added najran
# Retrieve data city no. 147 of 626|Added waiuku
# Retrieve data city no. 148 of 626|Added richards bay
# Retrieve data city no. 149 of 626|Added londa
# Retrieve data city no. 150 of 626|Added saskylakh
# Missing data city no. 151 of 626|Skipped samusu
# Retrieve data city no. 152 of 626|Added eyl
# Retrieve data city no. 153 of 626|Added makinsk
# Retrieve data city no. 154 of 626|Added margate
# Retrieve data city no. 155 of 626|Added ancud
# Retrieve data city no. 156 of 626|Added mogwase
# Retrieve data city no. 157 of 626|Added hurricane
# Missing data city no. 158 of 626|Skipped kerteh
# Retrieve data city no. 159 of 626|Added trujillo
# Retrieve data city no. 160 of 626|Added teguise
# Retrieve data city no. 161 of 626|Added shache
# Retrieve data city no. 162 of 626|Added waingapu
# Retrieve data city no. 163 of 626|Added jalalabad
# Retrieve data city no. 164 of 626|Added umm kaddadah
# Retrieve data city no. 165 of 626|Added lakhdenpokhya
# Retrieve data city no. 166 of 626|Added teya
# Retrieve data city no. 167 of 626|Added peniche
# Retrieve data city no. 168 of 626|Added rawson
# Retrieve data city no. 169 of 626|Added racine
# Retrieve data city no. 170 of 626|Added guatape
# Retrieve data city no. 171 of 626|Added vostok
# Retrieve data city no. 172 of 626|Added loukhi
# Retrieve data city no. 173 of 626|Added lorengau
# Retrieve data city no. 174 of 626|Added port elizabeth
# Retrieve data city no. 175 of 626|Added deputatskiy
# Retrieve data city no. 176 of 626|Added dikson
# Retrieve data city no. 177 of 626|Added lifford
# Retrieve data city no. 178 of 626|Added mar del plata
# Retrieve data city no. 179 of 626|Added korla
# Retrieve data city no. 180 of 626|Added presidencia roque saenz pena
# Retrieve data city no. 181 of 626|Added fort morgan
# Retrieve data city no. 182 of 626|Added novyy urengoy
# Retrieve data city no. 183 of 626|Added kysyl-syr
# Retrieve data city no. 184 of 626|Added pisco
# Retrieve data city no. 185 of 626|Added lebu
# Retrieve data city no. 186 of 626|Added hailar
# Retrieve data city no. 187 of 626|Added fortuna
# Retrieve data city no. 188 of 626|Added kruisfontein
# Retrieve data city no. 189 of 626|Added san quintin
# Retrieve data city no. 190 of 626|Added khatanga
# Missing data city no. 191 of 626|Skipped tillabery
# Retrieve data city no. 192 of 626|Added mogadishu
# Retrieve data city no. 193 of 626|Added barentu
# Retrieve data city no. 194 of 626|Added sorland
# Retrieve data city no. 195 of 626|Added ahuimanu
# Retrieve data city no. 196 of 626|Added tra vinh
# Retrieve data city no. 197 of 626|Added tocopilla
# Retrieve data city no. 198 of 626|Added palana
# Retrieve data city no. 199 of 626|Added shingu
# Retrieve data city no. 200 of 626|Added yangjiang
# Retrieve data city no. 201 of 626|Added ahipara
# Missing data city no. 202 of 626|Skipped barentsburg
# Retrieve data city no. 203 of 626|Added mashhad
# Missing data city no. 204 of 626|Skipped amderma
# Retrieve data city no. 205 of 626|Added lodwar
# Retrieve data city no. 206 of 626|Added pemangkat
# Retrieve data city no. 207 of 626|Added saskatoon
# Missing data city no. 208 of 626|Skipped mys shmidta
# Retrieve data city no. 209 of 626|Added roma
# Retrieve data city no. 210 of 626|Added shyryayeve
# Retrieve data city no. 211 of 626|Added svetlaya
# Retrieve data city no. 212 of 626|Added longyearbyen
# Retrieve data city no. 213 of 626|Added sao joao da barra
# Retrieve data city no. 214 of 626|Added bonavista
# Retrieve data city no. 215 of 626|Added ingham
# Retrieve data city no. 216 of 626|Added airai
# Missing data city no. 217 of 626|Skipped palabuhanratu
# Retrieve data city no. 218 of 626|Added henties bay
# Retrieve data city no. 219 of 626|Added carnarvon
# Retrieve data city no. 220 of 626|Added shubarkuduk
# Retrieve data city no. 221 of 626|Added jalu
# Retrieve data city no. 222 of 626|Added balkhash
# Retrieve data city no. 223 of 626|Added junnar
# Retrieve data city no. 224 of 626|Added colac
# Retrieve data city no. 225 of 626|Added broken hill
# Retrieve data city no. 226 of 626|Added sao jose da coroa grande
# Retrieve data city no. 227 of 626|Added san cristobal
# Retrieve data city no. 228 of 626|Added luderitz
# Retrieve data city no. 229 of 626|Added palmerston
# Retrieve data city no. 230 of 626|Added sasina
# Retrieve data city no. 231 of 626|Added opatovice nad labem
# Retrieve data city no. 232 of 626|Added kjollefjord
# Retrieve data city no. 233 of 626|Added ambon
# Retrieve data city no. 234 of 626|Added cidreira
# Retrieve data city no. 235 of 626|Added faanui
# Retrieve data city no. 236 of 626|Added bahir dar
# Retrieve data city no. 237 of 626|Added nelson bay
# Retrieve data city no. 238 of 626|Added dauphin
# Retrieve data city no. 239 of 626|Added comodoro rivadavia
# Retrieve data city no. 240 of 626|Added tessalit
# Retrieve data city no. 241 of 626|Added sao borja
# Retrieve data city no. 242 of 626|Added warri
# Retrieve data city no. 243 of 626|Added bambanglipuro
# Retrieve data city no. 244 of 626|Added qaqortoq
# Retrieve data city no. 245 of 626|Added ponta do sol
# Retrieve data city no. 246 of 626|Added arman
# Retrieve data city no. 247 of 626|Added byron bay
# Retrieve data city no. 248 of 626|Added maldonado
# Retrieve data city no. 249 of 626|Added belyy yar
# Retrieve data city no. 250 of 626|Added qaanaaq
# Retrieve data city no. 251 of 626|Added kavaratti
# Retrieve data city no. 252 of 626|Added tiksi
# Retrieve data city no. 253 of 626|Added vila velha
# Retrieve data city no. 254 of 626|Added castro
# Retrieve data city no. 255 of 626|Added waterford
# Retrieve data city no. 256 of 626|Added kualakapuas
# Retrieve data city no. 257 of 626|Added moose factory
# Retrieve data city no. 258 of 626|Added udachnyy
# Retrieve data city no. 259 of 626|Added taga
# Retrieve data city no. 260 of 626|Added paracuru
# Retrieve data city no. 261 of 626|Added kununurra
# Retrieve data city no. 262 of 626|Added itaituba
# Missing data city no. 263 of 626|Skipped tiruvottiyur
# Retrieve data city no. 264 of 626|Added asadabad
# Retrieve data city no. 265 of 626|Added dingle
# Retrieve data city no. 266 of 626|Added hilo
# Retrieve data city no. 267 of 626|Added brigantine
# Retrieve data city no. 268 of 626|Added rock springs
# Retrieve data city no. 269 of 626|Added severo-kurilsk
# Retrieve data city no. 270 of 626|Added lamu
# Missing data city no. 271 of 626|Skipped louisbourg
# Retrieve data city no. 272 of 626|Added abu samrah
# Retrieve data city no. 273 of 626|Added victoria
# Retrieve data city no. 274 of 626|Added aksu
# Retrieve data city no. 275 of 626|Added viesca
# Retrieve data city no. 276 of 626|Added faya
# Retrieve data city no. 277 of 626|Added mahibadhoo
# Retrieve data city no. 278 of 626|Added zaysan
# Retrieve data city no. 279 of 626|Added nikolskoye
# Retrieve data city no. 280 of 626|Added denpasar
# Retrieve data city no. 281 of 626|Added burnie
# Retrieve data city no. 282 of 626|Added falun
# Retrieve data city no. 283 of 626|Added hasaki
# Retrieve data city no. 284 of 626|Added mount isa
# Retrieve data city no. 285 of 626|Added cap malheureux
# Retrieve data city no. 286 of 626|Added redondela
# Missing data city no. 287 of 626|Skipped sentyabrskiy
# Retrieve data city no. 288 of 626|Added florianopolis
# Missing data city no. 289 of 626|Skipped khonuu
# Retrieve data city no. 290 of 626|Added komsomolsk
# Retrieve data city no. 291 of 626|Added vyazemskiy
# Retrieve data city no. 292 of 626|Added maniitsoq
# Retrieve data city no. 293 of 626|Added tateyama
# Retrieve data city no. 294 of 626|Added nantucket
# Missing data city no. 295 of 626|Skipped tabiauea
# Retrieve data city no. 296 of 626|Added kirakira
# Retrieve data city no. 297 of 626|Added ottumwa
# Retrieve data city no. 298 of 626|Added kromy
# Retrieve data city no. 299 of 626|Added nara
# Retrieve data city no. 300 of 626|Added nehe
# Retrieve data city no. 301 of 626|Added ostrovnoy
# Retrieve data city no. 302 of 626|Added saint-philippe
# Retrieve data city no. 303 of 626|Added mahebourg
# Retrieve data city no. 304 of 626|Added tukrah
# Retrieve data city no. 305 of 626|Added tual
# Retrieve data city no. 306 of 626|Added winton
# Retrieve data city no. 307 of 626|Added batticaloa
# Retrieve data city no. 308 of 626|Added axim
# Missing data city no. 309 of 626|Skipped marcona
# Retrieve data city no. 310 of 626|Added ribeira grande
# Retrieve data city no. 311 of 626|Added port hedland
# Retrieve data city no. 312 of 626|Added caborca
# Retrieve data city no. 313 of 626|Added chalon-sur-saone
# Retrieve data city no. 314 of 626|Added sungaipenuh
# Retrieve data city no. 315 of 626|Added nouadhibou
# Retrieve data city no. 316 of 626|Added camacha
# Retrieve data city no. 317 of 626|Added minusinsk
# Retrieve data city no. 318 of 626|Added taksimo
# Retrieve data city no. 319 of 626|Added venice
# Retrieve data city no. 320 of 626|Added bambous virieux
# Retrieve data city no. 321 of 626|Added maarianhamina
# Retrieve data city no. 322 of 626|Added vicuna
# Retrieve data city no. 323 of 626|Added tahoua
# Retrieve data city no. 324 of 626|Added opuwo
# Retrieve data city no. 325 of 626|Added kiunga
# Missing data city no. 326 of 626|Skipped nizhneyansk
# Retrieve data city no. 327 of 626|Added poplar bluff
# Retrieve data city no. 328 of 626|Added thaton
# Retrieve data city no. 329 of 626|Added buin
# Missing data city no. 330 of 626|Skipped yanchukan
# Retrieve data city no. 331 of 626|Added saint george
# Retrieve data city no. 332 of 626|Added aklavik
# Retrieve data city no. 333 of 626|Added teruel
# Retrieve data city no. 334 of 626|Added arawa
# Missing data city no. 335 of 626|Skipped suao
# Retrieve data city no. 336 of 626|Added tecoanapa
# Retrieve data city no. 337 of 626|Added saint andrews
# Retrieve data city no. 338 of 626|Added hambantota
# Retrieve data city no. 339 of 626|Added yamandu
# Missing data city no. 340 of 626|Skipped malwan
# Retrieve data city no. 341 of 626|Added bonga
# Retrieve data city no. 342 of 626|Added bathsheba
# Retrieve data city no. 343 of 626|Added raga
# Retrieve data city no. 344 of 626|Added aktash
# Retrieve data city no. 345 of 626|Added hauterive
# Retrieve data city no. 346 of 626|Added mglin
# Retrieve data city no. 347 of 626|Added kremenchuk
# Missing data city no. 348 of 626|Skipped doctor pedro p. pena
# Retrieve data city no. 349 of 626|Added gweta
# Retrieve data city no. 350 of 626|Added isla mujeres
# Retrieve data city no. 351 of 626|Added lagoa
# Retrieve data city no. 352 of 626|Added shimoda
# Retrieve data city no. 353 of 626|Added poya
# Retrieve data city no. 354 of 626|Added nabire
# Retrieve data city no. 355 of 626|Added kahului
# Retrieve data city no. 356 of 626|Added bellmead
# Retrieve data city no. 357 of 626|Added monrovia
# Retrieve data city no. 358 of 626|Added quanzhou
# Missing data city no. 359 of 626|Skipped dzhusaly
# Retrieve data city no. 360 of 626|Added severobaykalsk
# Retrieve data city no. 361 of 626|Added hanmer springs
# Retrieve data city no. 362 of 626|Added beringovskiy
# Retrieve data city no. 363 of 626|Added superior
# Retrieve data city no. 364 of 626|Added walvis bay
# Retrieve data city no. 365 of 626|Added acajutla
# Retrieve data city no. 366 of 626|Added abha
# Retrieve data city no. 367 of 626|Added xining
# Retrieve data city no. 368 of 626|Added xingcheng
# Retrieve data city no. 369 of 626|Added halifax
# Retrieve data city no. 370 of 626|Added narasannapeta
# Retrieve data city no. 371 of 626|Added san patricio
# Retrieve data city no. 372 of 626|Added baykit
# Retrieve data city no. 373 of 626|Added santa rosa
# Retrieve data city no. 374 of 626|Added nusaybin
# Retrieve data city no. 375 of 626|Added galesong
# Retrieve data city no. 376 of 626|Added dwarka
# Retrieve data city no. 377 of 626|Added coahuayana
# Retrieve data city no. 378 of 626|Added northam
# Retrieve data city no. 379 of 626|Added orange walk
# Retrieve data city no. 380 of 626|Added hobyo
# Retrieve data city no. 381 of 626|Added jingdezhen
# Retrieve data city no. 382 of 626|Added bairiki
# Retrieve data city no. 383 of 626|Added novoagansk
# Retrieve data city no. 384 of 626|Added biak
# Retrieve data city no. 385 of 626|Added tabas
# Retrieve data city no. 386 of 626|Added petropavlovsk-kamchatskiy
# Retrieve data city no. 387 of 626|Added sydney
# Retrieve data city no. 388 of 626|Added summerville
# Retrieve data city no. 389 of 626|Added kondinskoye
# Retrieve data city no. 390 of 626|Added coihaique
# Retrieve data city no. 391 of 626|Added half moon bay
# Retrieve data city no. 392 of 626|Added tambun
# Retrieve data city no. 393 of 626|Added bhadra
# Retrieve data city no. 394 of 626|Added zonguldak
# Retrieve data city no. 395 of 626|Added isangel
# Retrieve data city no. 396 of 626|Added port lincoln
# Retrieve data city no. 397 of 626|Added bose
# Retrieve data city no. 398 of 626|Added klyuchi
# Retrieve data city no. 399 of 626|Added aguimes
# Retrieve data city no. 400 of 626|Added amazar
# Retrieve data city no. 401 of 626|Added grindavik
# Retrieve data city no. 402 of 626|Added kargasok
# Retrieve data city no. 403 of 626|Added mehamn
# Retrieve data city no. 404 of 626|Added butembo
# Retrieve data city no. 405 of 626|Added linxia
# Retrieve data city no. 406 of 626|Added shenjiamen
# Retrieve data city no. 407 of 626|Added galveston
# Retrieve data city no. 408 of 626|Added atambua
# Retrieve data city no. 409 of 626|Added balaipungut
# Retrieve data city no. 410 of 626|Added san carlos de bariloche
# Retrieve data city no. 411 of 626|Added abu dhabi
# Missing data city no. 412 of 626|Skipped rungata
# Retrieve data city no. 413 of 626|Added cherepovets
# Retrieve data city no. 414 of 626|Added pimentel
# Missing data city no. 415 of 626|Skipped kamenskoye
# Retrieve data city no. 416 of 626|Added bujanovac
# Retrieve data city no. 417 of 626|Added klaksvik
# Retrieve data city no. 418 of 626|Added talnakh
# Retrieve data city no. 419 of 626|Added mombetsu
# Retrieve data city no. 420 of 626|Added kenitra
# Retrieve data city no. 421 of 626|Added maceio
# Missing data city no. 422 of 626|Skipped attawapiskat
# Retrieve data city no. 423 of 626|Added clyde river
# Retrieve data city no. 424 of 626|Added naze
# Retrieve data city no. 425 of 626|Added vanimo
# Retrieve data city no. 426 of 626|Added zakamensk
# Retrieve data city no. 427 of 626|Added sept-iles
# Retrieve data city no. 428 of 626|Added wichita falls
# Retrieve data city no. 429 of 626|Added havoysund
# Retrieve data city no. 430 of 626|Added brae
# Retrieve data city no. 431 of 626|Added morro bay
# Retrieve data city no. 432 of 626|Added auki
# Missing data city no. 433 of 626|Skipped toliary
# Retrieve data city no. 434 of 626|Added santiago de cuba
# Retrieve data city no. 435 of 626|Added ulaanbaatar
# Retrieve data city no. 436 of 626|Added la ronge
# Retrieve data city no. 437 of 626|Added suluq
# Retrieve data city no. 438 of 626|Added magadan
# Missing data city no. 439 of 626|Skipped rawannawi
# Retrieve data city no. 440 of 626|Added edmonds
# Retrieve data city no. 441 of 626|Added villefranche-de-rouergue
# Retrieve data city no. 442 of 626|Added saiha
# Retrieve data city no. 443 of 626|Added caravelas
# Retrieve data city no. 444 of 626|Added betare oya
# Retrieve data city no. 445 of 626|Added the pas
# Retrieve data city no. 446 of 626|Added tasiilaq
# Retrieve data city no. 447 of 626|Added hualmay
# Retrieve data city no. 448 of 626|Added praia da vitoria
# Retrieve data city no. 449 of 626|Added ola
# Retrieve data city no. 450 of 626|Added rio grande da serra
# Retrieve data city no. 451 of 626|Added provideniya
# Retrieve data city no. 452 of 626|Added paita
# Retrieve data city no. 453 of 626|Added areia branca
# Retrieve data city no. 454 of 626|Added pucallpa
# Missing data city no. 455 of 626|Skipped afgoye
# Retrieve data city no. 456 of 626|Added kabakovo
# Retrieve data city no. 457 of 626|Added siyabuswa
# Retrieve data city no. 458 of 626|Added mzimba
# Retrieve data city no. 459 of 626|Added coquimbo
# Retrieve data city no. 460 of 626|Added brownsville
# Retrieve data city no. 461 of 626|Added porto nacional
# Retrieve data city no. 462 of 626|Added honiara
# Retrieve data city no. 463 of 626|Added nampula
# Retrieve data city no. 464 of 626|Added miramar
# Retrieve data city no. 465 of 626|Added tiarei
# Retrieve data city no. 466 of 626|Added inhambane
# Retrieve data city no. 467 of 626|Added gravdal
# Retrieve data city no. 468 of 626|Added buenos aires
# Retrieve data city no. 469 of 626|Added saldanha
# Retrieve data city no. 470 of 626|Added shirokiy
# Retrieve data city no. 471 of 626|Added vila franca do campo
# Retrieve data city no. 472 of 626|Added las tablas
# Retrieve data city no. 473 of 626|Added inirida
# Missing data city no. 474 of 626|Skipped mullaitivu
# Retrieve data city no. 475 of 626|Added saint-pierre
# Retrieve data city no. 476 of 626|Added portland
# Retrieve data city no. 477 of 626|Added lompoc
# Retrieve data city no. 478 of 626|Added lazaro cardenas
# Retrieve data city no. 479 of 626|Added bundaberg
# Retrieve data city no. 480 of 626|Added skoghall
# Retrieve data city no. 481 of 626|Added arlit
# Retrieve data city no. 482 of 626|Added zhigalovo
# Missing data city no. 483 of 626|Skipped grand river south east
# Retrieve data city no. 484 of 626|Added mayya
# Retrieve data city no. 485 of 626|Added elban
# Retrieve data city no. 486 of 626|Added trairi
# Retrieve data city no. 487 of 626|Added saquarema
# Retrieve data city no. 488 of 626|Added tanout
# Retrieve data city no. 489 of 626|Added high prairie
# Retrieve data city no. 490 of 626|Added klodzko
# Retrieve data city no. 491 of 626|Added fare
# Retrieve data city no. 492 of 626|Added mecca
# Missing data city no. 493 of 626|Skipped bolshegrivskoye
# Retrieve data city no. 494 of 626|Added bilasipara
# Retrieve data city no. 495 of 626|Added la rochelle
# Retrieve data city no. 496 of 626|Added nacala
# Retrieve data city no. 497 of 626|Added santiago del estero
# Retrieve data city no. 498 of 626|Added gazli
# Retrieve data city no. 499 of 626|Added mopipi
# Retrieve data city no. 500 of 626|Added knysna
# Retrieve data city no. 501 of 626|Added bontang
# Retrieve data city no. 502 of 626|Added wright
# Retrieve data city no. 503 of 626|Added algiers
# Missing data city no. 504 of 626|Skipped bolungarvik
# Missing data city no. 505 of 626|Skipped liniere
# Retrieve data city no. 506 of 626|Added qasigiannguit
# Retrieve data city no. 507 of 626|Added uhlove
# Retrieve data city no. 508 of 626|Added verkhoyansk
# Retrieve data city no. 509 of 626|Added mwadui
# Retrieve data city no. 510 of 626|Added koslan
# Retrieve data city no. 511 of 626|Added karratha
# Retrieve data city no. 512 of 626|Added temryuk
# Retrieve data city no. 513 of 626|Added thunder bay
# Retrieve data city no. 514 of 626|Added yozgat
# Retrieve data city no. 515 of 626|Added bonfim
# Retrieve data city no. 516 of 626|Added torbay
# Retrieve data city no. 517 of 626|Added maningrida
# Retrieve data city no. 518 of 626|Added shancheng
# Retrieve data city no. 519 of 626|Added kon tum
# Retrieve data city no. 520 of 626|Added dudinka
# Retrieve data city no. 521 of 626|Added ostersund
# Retrieve data city no. 522 of 626|Added russell
# Missing data city no. 523 of 626|Skipped metehara
# Retrieve data city no. 524 of 626|Added mackay
# Retrieve data city no. 525 of 626|Added villacarrillo
# Retrieve data city no. 526 of 626|Added hays
# Retrieve data city no. 527 of 626|Added bat khela
# Retrieve data city no. 528 of 626|Added atar
# Retrieve data city no. 529 of 626|Added ajtos
# Retrieve data city no. 530 of 626|Added shestakovo
# Retrieve data city no. 531 of 626|Added vangaindrano
# Retrieve data city no. 532 of 626|Added pouembout
# Retrieve data city no. 533 of 626|Added vanjulet
# Retrieve data city no. 534 of 626|Added ibipora
# Retrieve data city no. 535 of 626|Added aksarka
# Retrieve data city no. 536 of 626|Added suifenhe
# Retrieve data city no. 537 of 626|Added linqu
# Retrieve data city no. 538 of 626|Added kimberley
# Retrieve data city no. 539 of 626|Added katherine
# Retrieve data city no. 540 of 626|Added soyo
# Retrieve data city no. 541 of 626|Added jiutai
# Retrieve data city no. 542 of 626|Added ormara
# Retrieve data city no. 543 of 626|Added athabasca
# Retrieve data city no. 544 of 626|Added seminole
# Retrieve data city no. 545 of 626|Added zemio
# Retrieve data city no. 546 of 626|Added novyy buyan
# Retrieve data city no. 547 of 626|Added trofors
# Retrieve data city no. 548 of 626|Added mazatlan
# Retrieve data city no. 549 of 626|Added ferrol
# Missing data city no. 550 of 626|Skipped tambaliza
# Retrieve data city no. 551 of 626|Added oranjemund
# Retrieve data city no. 552 of 626|Added plouzane
# Retrieve data city no. 553 of 626|Added price
# Retrieve data city no. 554 of 626|Added springfield
# Missing data city no. 555 of 626|Skipped vastervik
# Retrieve data city no. 556 of 626|Added leopold
# Retrieve data city no. 557 of 626|Added pontalina
# Retrieve data city no. 558 of 626|Added luoyang
# Retrieve data city no. 559 of 626|Added port blair
# Retrieve data city no. 560 of 626|Added christchurch
# Retrieve data city no. 561 of 626|Added yeroham
# Retrieve data city no. 562 of 626|Added esna
# Retrieve data city no. 563 of 626|Added takoradi
# Retrieve data city no. 564 of 626|Added hirara
# Missing data city no. 565 of 626|Skipped wahran
# Retrieve data city no. 566 of 626|Added krasnoselkup
# Retrieve data city no. 567 of 626|Added basoko
# Retrieve data city no. 568 of 626|Added los llanos de aridane
# Retrieve data city no. 569 of 626|Added jumla
# Retrieve data city no. 570 of 626|Added makakilo city
# Retrieve data city no. 571 of 626|Added kilindoni
# Retrieve data city no. 572 of 626|Added turukhansk
# Retrieve data city no. 573 of 626|Added saint-augustin
# Retrieve data city no. 574 of 626|Added xuzhou
# Retrieve data city no. 575 of 626|Added phonhong
# Retrieve data city no. 576 of 626|Added tyup
# Retrieve data city no. 577 of 626|Added loiza
# Retrieve data city no. 578 of 626|Added southbridge
# Retrieve data city no. 579 of 626|Added ampanihy
# Retrieve data city no. 580 of 626|Added shihezi
# Retrieve data city no. 581 of 626|Added guerrero negro
# Retrieve data city no. 582 of 626|Added te anau
# Retrieve data city no. 583 of 626|Added iwaki
# Retrieve data city no. 584 of 626|Added sao filipe
# Missing data city no. 585 of 626|Skipped mudyuga
# Retrieve data city no. 586 of 626|Added manzhouli
# Retrieve data city no. 587 of 626|Added amapa
# Retrieve data city no. 588 of 626|Added koungheul
# Retrieve data city no. 589 of 626|Added port hardy
# Retrieve data city no. 590 of 626|Added buchanan
# Retrieve data city no. 591 of 626|Added beyneu
# Retrieve data city no. 592 of 626|Added otsuchi
# Retrieve data city no. 593 of 626|Added saint anthony
# Retrieve data city no. 594 of 626|Added kyshtovka
# Retrieve data city no. 595 of 626|Added fort nelson
# Missing data city no. 596 of 626|Skipped santa eulalia del rio
# Retrieve data city no. 597 of 626|Added chara
# Missing data city no. 598 of 626|Skipped utiroa
# Retrieve data city no. 599 of 626|Added magaria
# Retrieve data city no. 600 of 626|Added ndele
# Retrieve data city no. 601 of 626|Added cortez
# Retrieve data city no. 602 of 626|Added kem
# Retrieve data city no. 603 of 626|Added quesnel
# Retrieve data city no. 604 of 626|Added viedma
# Retrieve data city no. 605 of 626|Added college
# Retrieve data city no. 606 of 626|Added tanda
# Retrieve data city no. 607 of 626|Added alyangula
# Retrieve data city no. 608 of 626|Added birobidzhan
# Retrieve data city no. 609 of 626|Added villa guerrero
# Missing data city no. 610 of 626|Skipped bocaranga
# Missing data city no. 611 of 626|Skipped verwoerdburg
# Retrieve data city no. 612 of 626|Added black river
# Retrieve data city no. 613 of 626|Added dakar
# Retrieve data city no. 614 of 626|Added san roque
# Retrieve data city no. 615 of 626|Added oksbol
# Retrieve data city no. 616 of 626|Added sokolka
# Retrieve data city no. 617 of 626|Added cody
# Retrieve data city no. 618 of 626|Added mabaruma
# Retrieve data city no. 619 of 626|Added idanre
# Retrieve data city no. 620 of 626|Added riyadh
# Retrieve data city no. 621 of 626|Added ketchikan
# Missing data city no. 622 of 626|Skipped kazalinsk
# Retrieve data city no. 623 of 626|Added issaquah
# Retrieve data city no. 624 of 626|Added lima
# Retrieve data city no. 625 of 626|Added pocatello
# Retrieve data city no. 626 of 626|Added touros
# ----------------------
# End of Data retrieval

# %%
weather_data=pd.DataFrame()
weather_dict={
    'City': cit,
    'Latitude': lat,
    'Longitude': long,
    'Max Temperature': temp_max,
    'Humidity': hum,
    'Cloudiness': cld,
    'Wind Speed': wind,
    'City Country': country,
    'City Date': date
}

weather_data=pd.DataFrame(weather_dict)

temp_max_celcus=[]
for temp in weather_data['Max Temperature']:
    new_temp= (int(temp)-273.15)*9/5+32
    temp_max_celcus.append(new_temp)
    

weather_dict_final={
    'City': cit,
    'Latitude': lat,
    'Longitude': long,
    'Max Temperature in Celsus': temp_max_celcus,
    'Humidity': hum,
    'Cloudiness': cld,
    'Wind Speed': wind,
    'City Country': country,
    'City Date': date
}

weather_data_final=pd.DataFrame(weather_dict_final)

weather_data.to_csv('PyWeatherTable.csv',index=False)

weather_data_final
# Out:
#                City  Latitude  Longitude  Max Temperature in Celsus  Humidity  \
# 0              chuy    -33.70     -53.46                      67.73        60
# 1             casma    -41.01     -73.12                      58.73        87
# 2          hermanus    -34.42      19.23                      65.93        89
# 3           iralaya     15.00     -83.23                      87.53        66
# 4       east london    -33.02      27.91                      69.53        78
# 5             sitka     57.05    -135.33                      37.13        69
# 6             pevek     69.70     170.31                      -4.27        85
# 7              tura     25.52      90.22                      73.13        35
# 8       yellowknife     62.46    -114.35                      11.93        72
# 9            laguna     38.42    -121.42                      62.33        63
# 10         bengkulu     -3.80     102.27                      76.73        81
# 11        yeniseysk     58.45      92.17                      28.13        96
# 12           albany     42.60     -73.97                      44.33        48
# 13           bamako     12.65      -8.00                      98.33        17
# 14        fairbanks     64.84    -147.72                      15.53        78
# 15          rikitea    -23.12    -134.97                      76.73        75
# 16   cabo san lucas     22.89    -109.91                      74.93        77
# 17           broome     42.25     -75.83                      35.33        86
# 18            alofi    -19.06    -169.92                      74.93        83
# 19          ushuaia    -54.80     -68.30                      46.13        70
# 20           narsaq     60.92     -46.05                      42.53        28
# 21         boralday     43.36      76.86                      35.33        48
# 22         guipavas     48.44      -4.40                      78.53        33
# 23           powell     40.16     -83.08                      46.13        45
# 24         katsuura     35.13     140.30                      47.93        36
# 25         souillac    -20.52      57.52                      78.53        78
# 26            kapaa     22.08    -159.32                      67.73        88
# 27     punta arenas    -53.15     -70.92                      47.93        66
# 28        taoudenni     22.68      -3.98                      98.33         8
# 29           atuona     -9.80    -139.03                      80.33        77
# ..              ...       ...        ...                        ...       ...
# 543         otsuchi     39.37     141.90                      35.33        82
# 544   saint anthony     45.02     -93.22                      44.33        41
# 545       kyshtovka     56.55      76.63                      29.93        97
# 546     fort nelson     58.81    -122.70                      24.53        41
# 547           chara     56.91     118.26                      28.13        67
# 548         magaria     13.00       8.91                      91.13        12
# 549           ndele      8.41      20.65                      82.13        44
# 550          cortez     37.35    -108.59                      56.93        22
# 551             kem     64.96      34.58                      26.33        91
# 552         quesnel     53.00    -122.50                      42.53        52
# 553          viedma    -40.81     -63.00                      76.73        28
# 554         college     64.86    -147.80                      15.53        78
# 555           tanda     26.55      82.65                      80.33        15
# 556       alyangula    -13.85     136.42                      74.93       100
# 557     birobidzhan     48.80     132.95                      33.53        79
# 558  villa guerrero     18.87     -99.65                      91.13        21
# 559     black river     18.03     -77.85                      85.73        70
# 560           dakar     14.69     -17.44                     100.13        69
# 561       san roque     36.21      -5.38                      69.53        72
# 562          oksbol     55.63       8.29                      47.93        70
# 563         sokolka     53.41      23.50                      49.73        34
# 564            cody     44.53    -109.06                      60.53        31
# 565        mabaruma      8.20     -59.78                      85.73        58
# 566          idanre      7.11       5.12                      80.33        60
# 567          riyadh     24.69      46.72                      91.13        14
# 568       ketchikan     55.34    -131.65                      38.93        69
# 569        issaquah     47.53    -122.03                      56.93        58
# 570            lima    -12.04     -77.03                      71.33        83
# 571       pocatello     42.87    -112.45                      56.93        41
# 572          touros     -5.20     -35.46                      87.53        62
#
#      Cloudiness  Wind Speed City Country   City Date
# 0             6        4.55           UY  1586539408
# 1            90        4.60           CL  1586539408
# 2             2        0.45           ZA  1586539774
# 3            75        2.60           HN  1586539774
# 4           100        4.66           ZA  1586539558
# 5             1        2.76           US  1586539774
# 6            32        9.31           RU  1586539728
# 7             0        2.03           IN  1586539775
# 8            20        6.20           CA  1586539479
# 9             1        1.50           US  1586539775
# 10           87        1.83           ID  1586539775
# 11           20        2.06           RU  1586539776
# 12           90        9.30           US  1586539776
# 13           44        2.69           ML  1586539776
# 14           90        1.50           US  1586539494
# 15           94        2.74           PF  1586539776
# 16           75        1.50           MX  1586539479
# 17           90        6.20           US  1586539777
# 18          100        2.10           NU  1586539727
# 19           75       10.30           AR  1586539777
# 20          100       21.10           GL  1586539777
# 21           75        2.00           KZ  1586539777
# 22            0        4.10           FR  1586539778
# 23           75        6.70           US  1586539778
# 24           48        6.70           JP  1586539778
# 25           40        6.20           MU  1586539778
# 26            1        3.10           US  1586539778
# 27           75        7.70           CL  1586539726
# 28            0        2.56           ML  1586539779
# 29           19        5.34           PF  1586539779
# ..          ...         ...          ...         ...
# 543          14        3.48           JP  1586539882
# 544           1        3.26           US  1586539882
# 545          54        3.46           RU  1586539882
# 546          75        4.10           CA  1586539882
# 547          56        0.72           RU  1586539883
# 548         100        6.91           NE  1586539883
# 549          61        1.61           CF  1586539883
# 550           1        4.10           US  1586539883
# 551          73        2.51           RU  1586539883
# 552           1        1.00           CA  1586539717
# 553           0        9.39           AR  1586539884
# 554          90        2.60           US  1586539676
# 555          10        1.32           IN  1586539884
# 556          90        3.52           AU  1586539884
# 557          74        2.72           RU  1586539884
# 558          40        3.10           MX  1586539884
# 559          20        6.70           JM  1586539885
# 560           0        6.20           SN  1586539835
# 561          20        6.20           ES  1586539885
# 562          53        5.70           DK  1586539885
# 563          75        8.00           PL  1586539885
# 564           1        5.70           US  1586539622
# 565         100        3.41           GY  1586539885
# 566          62        0.75           NG  1586539886
# 567         100        6.20           SA  1586539698
# 568          20       10.30           US  1586539594
# 569           1        2.60           US  1586539886
# 570          90        2.60           PE  1586539823
# 571           1        3.60           US  1586539635
# 572          40        5.70           BR  1586539887
#
# [573 rows x 9 columns]

# %%
#Send data to a database

# %%
total_cities=len(weather_data['City'])
timestamp=datetime.datetime.today()

plt.figure(0)
plt.scatter(x=weather_data['Latitude'],y=weather_data['Max Temperature'],c='green', edgecolor='Black', alpha=0.75,
           marker='o')
timestamp=datetime.datetime.today()
plt.title(f'Temperature (F) vs. Latitude \n {timestamp} \n Note: Sample of {total_cities} random cities')
plt.xlabel('Latitude')
plt.ylabel('Temparature')
plt.grid()
plt.savefig('TempvsLat.png')
plt.show()
